# %% [markdown]
# # importing needed library

# %%
#importing library 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading data set

# %%
df=pd.read_csv(r"D:\#python dataset\netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
df.tail(2)
# Out:
#      show_id   type   title      director  \
# 8805   s8806  Movie    Zoom  Peter Hewitt
# 8806   s8807  Movie  Zubaan   Mozez Singh
#
#                                                    cast        country  \
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
#                                             description
# 8805  Dragged from civilian life, a former superhero...
# 8806  A scrappy but poor boy worms his way into a ty...

# %% [markdown]
# # Q.1]  Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
#8807 rows 12 cols
df.shape
# Out:
# (8807, 12)

# %%
#no duplicate
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, listed_in, description]
# Index: []

# %%
# all unique values
df["title"].nunique()
# Out:
# 8807

# %% [markdown]
# # Q.2] Is there any Null Value present in any column ? Show with Heat-map.

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# # Q.3] In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
Relese_year=df["release_year"].value_counts().head(10).plot(kind='bar',color=["orange","red",'blue','green','skyblue',"grey"]
                                     ,edgecolor='black',title="yearly releses of show")
Relese_year
# Out:
# <Axes: title={'center': 'yearly releses of show'}, xlabel='release_year'>

# %% [markdown]
# # Q.4] How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
df["type"].value_counts().plot(kind='bar',color=["red",'green'],edgecolor='black')
# Out:
# <Axes: xlabel='type'>

# %% [markdown]
#    # Q.5] Show all the Movies that were released in year 2000.

# %%
df[df["release_year"]==2000].shape                                                              #37 movies were realsed in 2000
# Out:
# (37, 12)

# %%
df[df["release_year"]==2000].head(5)
# Out:
#     show_id   type                               title        director  \
# 180    s181  Movie  The Nutty Professor II: The Klumps     Peter Segal
# 350    s351  Movie                       Space Cowboys  Clint Eastwood
# 359    s360  Movie        The Original Kings of Comedy       Spike Lee
# 566    s567  Movie                    Charlie's Angels             McG
# 593    s594  Movie                            Snow Day      Chris Koch
#
#                                                   cast  \
# 180  Eddie Murphy, Janet Jackson, Larry Miller, Joh...
# 350  Clint Eastwood, Tommy Lee Jones, Donald Suther...
# 359  Steve Harvey, D.L. Hughley, Cedric the Enterta...
# 566  Cameron Diaz, Drew Barrymore, Lucy Liu, Bill M...
# 593  Chris Elliott, Mark Webber, Jean Smart, Schuyl...
#
#                     country         date_added  release_year rating duration  \
# 180                     NaN  September 1, 2021          2000  PG-13  107 min
# ...

# %% [markdown]
#  # Q.6]Show only the Titles of all TV Shows that were released in India only.

# %%
df[(df["type"]=="TV Show") &(df["country"]=='India')].head(2)
# Out:
#    show_id     type         title director  \
# 4       s5  TV Show  Kota Factory      NaN
# 39     s40  TV Show  Chhota Bheem      NaN
#
#                                                  cast country  \
# 4   Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...   India
# 39  Vatsal Dubey, Julie Tejwani, Rupa Bhimani, Jig...   India
#
#             date_added  release_year rating   duration  \
# 4   September 24, 2021          2021  TV-MA  2 Seasons
# 39  September 16, 2021          2021  TV-Y7  3 Seasons
#
#                                             listed_in  \
# 4   International TV Shows, Romantic TV Shows, TV ...
# 39                                           Kids' TV
#
#                                           description
# 4   In a city of coaching centers known to train I...
# 39  A brave, energetic little boy with superhuman ...

# %% [markdown]
#  # Q.7] Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df["director"].value_counts().sort_values(ascending=False).head(10)      #top 10 director
# Out:
# director
# Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Suhas Kadav               16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Jay Chapman               12
# Martin Scorsese           12
# Steven Spielberg          11
# Name: count, dtype: int64

# %%
df["director"].value_counts().sort_values(ascending=False).head(10).plot(kind="bar",
                                title="Top 10 Director",edgecolor="black")
plt.show()

# %% [markdown]
#  # Q.8]Show all the Records, where "Category is Movie and Type is Documentry" or "Country is United Kingdom".

# %%
 filterd_data =df[(df["type"]=="Movie") & (df["listed_in"]=="Documentaries") | (df["country"]=="United Kingdom")]
 filterd_data
# Out:
#      show_id     type                            title         director  \
# 0         s1    Movie             Dick Johnson Is Dead  Kirsten Johnson
# 8         s9  TV Show    The Great British Baking Show  Andy Devonshire
# 32       s33  TV Show                    Sex Education              NaN
# 45       s46    Movie           My Heroes Were Cowboys      Tyler Greco
# 65       s66  TV Show                     Numberblocks              NaN
# ...      ...      ...                              ...              ...
# 8741   s8742  TV Show                      Wild Arabia              NaN
# 8744   s8745    Movie                         Williams  Morgan Matthews
# 8758   s8759  TV Show           World's Busiest Cities              NaN
# 8763   s8764    Movie  WWII: Report from the Aleutians      John Huston
# 8786   s8787    Movie                     You Can Tutu      James Brown
#
#                                                    cast         country  \
# ...

# %% [markdown]
#  #  Q.9]  For 'The original Kings of comedy', what is the Show Id and Who is the Director of this show ?

# %%
# two method o find in columns
#isin() method first
df[df["title"].isin(["The Original Kings of Comedy"])]
# Out:
#     show_id   type                         title   director  \
# 359    s360  Movie  The Original Kings of Comedy  Spike Lee
#
#                                                   cast        country  \
# 359  Steve Harvey, D.L. Hughley, Cedric the Enterta...  United States
#
#          date_added  release_year rating duration        listed_in  \
# 359  August 1, 2021          2000      R  111 min  Stand-Up Comedy
#
#                                            description
# 359  Comedians Steve Harvey, Cedric the Entertainer...

# %%
#second is str.contains()
df[df["title"].str.contains("The Original Kings of Comedy")]
# Out:
#     show_id   type                         title   director  \
# 359    s360  Movie  The Original Kings of Comedy  Spike Lee
#
#                                                   cast        country  \
# 359  Steve Harvey, D.L. Hughley, Cedric the Enterta...  United States
#
#          date_added  release_year rating duration        listed_in  \
# 359  August 1, 2021          2000      R  111 min  Stand-Up Comedy
#
#                                            description
# 359  Comedians Steve Harvey, Cedric the Entertainer...

# %% [markdown]
#  #  Q.10] How many Movies got the 'TV-14' rating, in Canada ?

# %%
#unique() rating values
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
listed_in_canda=df[(df["type"]=="Movie") & (df["rating"]=="TV-14") &(df["country"]=='Canada')]
listed_in_canda.head(2)
# Out:
#      show_id   type                                       title  \
# 157     s158  Movie                                    Level 16
# 1279   s1280  Movie  Made You Look: A True Story About Fake Art
#
#                 director                                               cast  \
# 157   Danishka Esterhazy  Katie Douglas, Celina Martin, Peter Outerbridg...
# 1279        Barry Avrich                                                NaN
#
#      country         date_added  release_year rating duration  \
# 157   Canada  September 1, 2021          2018  TV-14  102 min
# 1279  Canada  February 23, 2021          2020  TV-14   90 min
#
#                                 listed_in  \
# 157           Sci-Fi & Fantasy, Thrillers
# 1279  Documentaries, International Movies
#
#                                             description
# 157   In a bleak academy that teaches girls the virt...
# 1279  A woman walks into a New York gallery with a c...

# %% [markdown]
# # Q.11] What is the maximum duration of a Movie/Show on Netflix ?

# %%
df["duration"].sort_values(ascending=False).head(5)
# Out:
# 1329    99 min
# 6278    99 min
# 952     99 min
# 6141    99 min
# 929     99 min
# Name: duration, dtype: object

# %% [markdown]
# # Q.12] Which individual country has the Highest No. of TV Shows ?

# %%
country=df[df["type"]=="TV Show"]

# %%
country.country.value_counts().head(5)
# Out:
# country
# United States     760
# United Kingdom    213
# Japan             169
# South Korea       158
# India              79
# Name: count, dtype: int64

# %% [markdown]
# #  Q.13]How can we sort the dataset by Year

# %%
df["release_year"].sort_values(ascending=False)
# Out:
# 693     2021
# 781     2021
# 762     2021
# 763     2021
# 764     2021
#         ...
# 8660    1943
# 8763    1943
# 8205    1942
# 7790    1942
# 4250    1925
# Name: release_year, Length: 8807, dtype: int64

# %% [markdown]
#  # Q.14] Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df["listed_in"].nunique()
# Out:
# 514

# %%
df[(df["type"]=="Movie")&(df["listed_in"]=="Dramas")|(df["type"]=="TV SHOW") & (df["listed_in"]=="Kids")]
# Out:
#      show_id   type                title             director  \
# 112     s113  Movie                Worth       Sara Colangelo
# 129     s130  Movie   An Unfinished Life      Lasse Hallström
# 142     s143  Movie      Freedom Writers  Richard LaGravenese
# 162     s163  Movie             Marshall      Reginald Hudlin
# 329     s330  Movie  Catch Me If You Can     Steven Spielberg
# ...      ...    ...                  ...                  ...
# 8674   s8675  Movie      Viceroy's House      Gurinder Chadha
# 8675   s8676  Movie               Victor    Brandon Dickerson
# 8685   s8686  Movie                  VS.             Ed Lilly
# 8691   s8692  Movie            Wakefield        Robin Swicord
# 8696   s8697  Movie            War Horse     Steven Spielberg
#
#                                                    cast  \
# 112   Michael Keaton, Stanley Tucci, Amy Ryan, Shuno...
# 129   Robert Redford, Jennifer Lopez, Morgan Freeman...
# ...

# %% [markdown]
# # ___________THANKYOU FOR WATCHING___________
